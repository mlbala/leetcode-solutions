# %%
print('Hello World')
# Out:
# Hello World

# %%
"Hellow World 7"
'Hello World 8'
# Out:
# 'Hello World 8'

# %%
type('Hello World 8')
# Out:
# str

# %%
"My name is Bala and I am 30 years old"
# Out:
# 'My name is Bala and I am 30 years old'

# %%
"23"
# Out:
# '23'

# %%
"23" + "4"
# Out:
# '234'

# %%
23
# Out:
# 23

# %%
"Hello" + "World"
# Out:
# 'HelloWorld'

# %%
23 + 4
# Out:
# 27

# %%
"Hello" - "Hi"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e0659a3f56e7> in <cell line: 0>()
# ----> 1 "Hello" - "Hi"
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
3 - 2
# Out:
# 1

# %%
"Hello" + "hi
print("hi")
# Out:
#   File "<ipython-input-14-b897cd417de5>", line 1
#     "Hello" + "hi
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"Hello" + "hi"
print("hi")
# Out:
# hi

# %%
type(3)
# Out:
# int

# %%
type(3.5)
# Out:
# float

# %%
3.4 + 5.6
# Out:
# 9.0

# %%
type(3.4 + 5.6)
# Out:
# float

# %%
4 * 3
# Out:
# 12

# %%
2.1 * 3.2
# Out:
# 6.720000000000001

# %%
4/3
# Out:
# 1.3333333333333333

# %%
1/1
# Out:
# 1.0

# %%
type(1/1)
# Out:
# float

# %%
3.2 / 1.6
# Out:
# 2.0

# %%
3 // 2
# Out:
# 1

# %%
type(3 // 2)
# Out:
# int

# %%
5 // 2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
5 % 2
# Out:
# 1

# %%
5 * 5
# Out:
# 25

# %%
5 * 5 * 5
# Out:
# 125

# %%
5 ** 3
# Out:
# 125

# %%
x = 5

# %%
x
# Out:
# 5

# %%
 x = "tree"
 x
# Out:
# 'tree'

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
"True"
# Out:
# 'True'

# %%
type(True)
# Out:
# bool

# %%
4 < 3
# Out:
# False

# %%
4 > 3
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
3 >= 2
# Out:
# True

# %%
3 <= 2
# Out:
# False

# %%
3 >= 3
# Out:
# True

# %%
3 <= 3
# Out:
# True

# %%
2 != 3
# Out:
# True

# %%
3 != 2
# Out:
# True

# %%
x = 2

# %%
3 = 2
# Out:
#   File "<ipython-input-57-bdaf9486a94f>", line 1
#     3 = 2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
3 == 2
# Out:
# False

# %%
"hi" == "hi"
# Out:
# True

# %%
3.2 > 5
# Out:
# False

# %%
True
# Out:
# True

# %%
if True:
  print(1)
  print(2)
# Out:
# 1
# 2

# %%
if True:
  print(1)
  print(2)

print(3)
# Out:
# 1
# 2
# 3

# %%
if False:
  print(1)
  print(2)

print(3)
# Out:
# 3

# %%
if 8 > 7:
  print(1)
  print(2)

print(3)
# Out:
# 1
# 2
# 3

# %%
if 8 < 7:
  print(1)
  print(2)

print(3)
# Out:
# 3

# %%
banana = "banana"
orange = "orange"

# %%
grocery_list = ["banana", "orange", "blueberries"]
grocery_list
# Out:
# ['banana', 'orange', 'blueberries']

# %%
grocery_list.append("apple")
grocery_list
# Out:
# ['banana', 'orange', 'blueberries', 'apple']

# %%
type(grocery_list)
# Out:
# list

# %%
for item in grocery_list:
  print(item)
# Out:
# banana
# orange
# blueberries
# apple

# %%
grocery_list[0]
# Out:
# 'banana'

# %%
grocery_list[1]
# Out:
# 'orange'

# %%
grocery_list[2]
# Out:
# 'blueberries'

# %%
grocery_list[3]
# Out:
# 'apple'

# %%
grocery_list[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-78-0b6d988cbc3d> in <cell line: 0>()
# ----> 1 grocery_list[4]
#
# IndexError: list index out of range

# %%
for i in [0,1,2,3]:
  print(grocery_list[i])
# Out:
# banana
# orange
# blueberries
# apple

# %%
for i in range(4):
  print(grocery_list[i])
# Out:
# banana
# orange
# blueberries
# apple

# %%
list(range(len(grocery_list)))
# Out:
# [0, 1, 2, 3]

# %%
for i, item in enumerate(grocery_list):
  print(i, item)
# Out:
# 0 banana
# 1 orange
# 2 blueberries
# 3 apple

# %%
i = 0
i += 1

i
# Out:
# 1

# %%
i+= 1
i
# Out:
# 3

# %%
i -= 1
i
# Out:
# 2

# %%
grocery_list
# Out:
# ['banana', 'orange', 'blueberries', 'apple']

# %%
j = len(grocery_list) - 1

while j >= 0:
  print(grocery_list[j])
  j -= 1

print('end')
# Out:
# apple
# blueberries
# orange
# banana
# end

# %%
i = 0

while i < len(grocery_list):
  print(grocery_list[i])
  i += 1

print('end')
# Out:
# banana
# orange
# blueberries
# apple
# end

# %%
if False:
  print(1)
elif False:
  print(2)
else:
  print(3)
# Out:
# 3

# %%
if True:
  print(1)
  print("1a")
elif False:
  print(2)
else:
  print(3)

print("end")
# Out:
# 1
# 1a
# end

# %%
if False:
  print(1)
elif False:
  print(2)
elif True:
  print(3)
else:
  print(4)

print("end")
# Out:
# 3
# end

# %%
if False:
  print(1)
elif False:
  print(2)
elif False:
  print(3)
else:
  print(4)

print("end")
# Out:
# 4
# end

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
(5>6) or (4<5)
# Out:
# True

# %%
age = 18

if age < 1:
  print("New born")
elif age < 5:
  print("Young")
elif age < 10:
  print("Child")
elif age < 18:
  print("Teen")
else:
  print("Adult")

print("end")
# Out:
# Adult
# end

# %%
age = 17

if age <= 1:
  print("Newborn")
elif(age >= 13) and (age <= 19):
  print("Teen")
else:
  print("Adult")

print("end")
# Out:
# Teen
# end

# %% [markdown]
# ## Functions

# %%
print("Hi 2")
# Out:
# Hi 2

# %%
# Function to print only single string

def our_print(string):
  print(string)

our_print("hi 2")
# Out:
# hi 2

# %%
def times_2(x):
  return x*2

times_2(5)
# Out:
# 10

# %%
print(None)
# Out:
# None

# %%
def append_4_to_list(lst):
  lst.append(4)
  return lst

a = [1,2,3]
append_4_to_list(a)
# Out:
# [1, 2, 3, 4]

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
def times_2(x):
  return x*2

b=4
times_2(b)
# Out:
# 8

# %%
b
# Out:
# 4
